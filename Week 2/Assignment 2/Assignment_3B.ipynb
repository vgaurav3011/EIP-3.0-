# %% [markdown]
# <a href="https://colab.research.google.com/github/vgaurav3011/EIP-3.0-/blob/master/Assignment_3B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://keras.io/
# !pip install -q keras
import keras

import keras
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
from keras.optimizers import Adam
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
from keras.layers.merge import concatenate

# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# Hyperparameters
batch_size = 128
num_classes = 10
epochs = 50
l = 10
num_filter = 20
# Out:
# Using TensorFlow backend.

# %%
# Load CIFAR10 Data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_height, img_width, channel = x_train.shape[1],x_train.shape[2],x_train.shape[3]

# convert to one hot encoding 
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
input = Input(shape=(img_height, img_width, channel,))

# Layer 1
x01 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input)
x01 = BatchNormalization(name='norm_1')(x01)
x01 = LeakyReLU(alpha=0.1)(x01)
x01 = MaxPooling2D(pool_size=(2, 2))(x01)

# Layer 2
x02 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(x01)
x02 = BatchNormalization(name='norm_2')(x02)
x02 = LeakyReLU(alpha=0.1)(x02)
x02 = MaxPooling2D(pool_size=(2, 2))(x02)

# Layer 3
x03 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(x02)
x03 = BatchNormalization(name='norm_3')(x03)
x03 = LeakyReLU(alpha=0.1)(x03)

# Layer 4
x04 = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_4', use_bias=False)(x03)
x04 = BatchNormalization(name='norm_4')(x04)
x04 = LeakyReLU(alpha=0.1)(x04)

# Layer 5
x05 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(x04)
x05 = BatchNormalization(name='norm_5')(x05)
x05 = LeakyReLU(alpha=0.1)(x05)
x05 = MaxPooling2D(pool_size=(2, 2))(x05)

# Layer 6
x06 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(x05)
x06 = BatchNormalization(name='norm_6')(x06)
x06 = LeakyReLU(alpha=0.1)(x06)

# Layer 7
x07 = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_7', use_bias=False)(x06)
x07 = BatchNormalization(name='norm_7')(x07)
x07 = LeakyReLU(alpha=0.1)(x07)

# Layer 8
x08 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(x07)
x08 = BatchNormalization(name='norm_8')(x08)
x08 = LeakyReLU(alpha=0.1)(x08)
x08 = MaxPooling2D(pool_size=(2, 2))(x08)

# Layer 9
x09 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(x08)
x09 = BatchNormalization(name='norm_9')(x09)
x09 = LeakyReLU(alpha=0.1)(x09)

# Layer 10
x10 = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_10', use_bias=False)(x09)
x10 = BatchNormalization(name='norm_10')(x10)
x10 = LeakyReLU(alpha=0.1)(x10)

# Layer 11
x11 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(x10)
x11 = BatchNormalization(name='norm_11')(x11)
x11 = LeakyReLU(alpha=0.1)(x11)

# Layer 12
x12 = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_12', use_bias=False)(x11)
x12 = BatchNormalization(name='norm_12')(x12)
x12 = LeakyReLU(alpha=0.1)(x12)

skip_connection = x12

# Layer 13
x13 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(x12)
x13 = BatchNormalization(name='norm_13')(x13)
x13 = LeakyReLU(alpha=0.1)(x13)

#skip_connection = x

x13 = MaxPooling2D(pool_size=(2, 2))(x13)

# Layer 14
x14 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(x13)
x14 = BatchNormalization(name='norm_14')(x14)
x14 = LeakyReLU(alpha=0.1)(x14)

# Layer 15
x15 = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_15', use_bias=False)(x14)
x15 = BatchNormalization(name='norm_15')(x15)
x15 = LeakyReLU(alpha=0.1)(x15)

# Layer 16
x16 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(x15)
x16 = BatchNormalization(name='norm_16')(x16)
x16 = LeakyReLU(alpha=0.1)(x16)

# Layer 17
x17 = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_17', use_bias=False)(x16)
x17 = BatchNormalization(name='norm_17')(x17)
x17 = LeakyReLU(alpha=0.1)(x17)

# Layer 18
x18 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(x17)
x18 = BatchNormalization(name='norm_18')(x18)
x18 = LeakyReLU(alpha=0.1)(x18)

# Layer 19
x19 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(x18)
x19 = BatchNormalization(name='norm_19')(x19)
x19 = LeakyReLU(alpha=0.1)(x19)

# Layer 20
x20 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(x19)
x20 = BatchNormalization(name='norm_20')(x20)
x20 = LeakyReLU(alpha=0.1)(x20)

# Layer 21
skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

x21 = concatenate([skip_connection, x20])

# Layer 22
x22 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(x21)
x22 = BatchNormalization(name='norm_22')(x22)
x22 = LeakyReLU(alpha=0.1)(x22)

# Layer 23
x23 = Flatten()(x22)

output = Dense(num_classes, activation='softmax')(x23)

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 32, 32, 32)   864         input_3[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 32, 32, 32)   128         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 32, 32, 32)   0           norm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 16, 16, 32)   0           leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 16, 16, 64)   18432       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 16, 16, 64)   256         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 16, 16, 64)   0           norm_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 8, 8, 64)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 8, 8, 128)    73728       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# norm_3 (BatchNormalization)     (None, 8, 8, 128)    512         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 8, 8, 128)    0           norm_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 8, 8, 64)     8192        leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 8, 8, 64)     256         conv_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 8, 8, 64)     0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 8, 8, 128)    73728       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 8, 8, 128)    512         conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 8, 8, 128)    0           norm_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 4, 4, 128)    0           leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 4, 4, 256)    294912      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 4, 4, 256)    1024        conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 4, 4, 256)    0           norm_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 4, 4, 128)    32768       leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# norm_7 (BatchNormalization)     (None, 4, 4, 128)    512         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 4, 4, 128)    0           norm_7[0][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, 4, 4, 256)    294912      leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# norm_8 (BatchNormalization)     (None, 4, 4, 256)    1024        conv_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 4, 4, 256)    0           norm_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 2, 2, 256)    0           leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 2, 2, 512)    1179648     max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# norm_9 (BatchNormalization)     (None, 2, 2, 512)    2048        conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 2, 2, 512)    0           norm_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 2, 2, 256)    131072      leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# norm_10 (BatchNormalization)    (None, 2, 2, 256)    1024        conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 2, 2, 256)    0           norm_10[0][0]
# __________________________________________________________________________________________________
# conv_11 (Conv2D)                (None, 2, 2, 512)    1179648     leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# norm_11 (BatchNormalization)    (None, 2, 2, 512)    2048        conv_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 2, 2, 512)    0           norm_11[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 2, 2, 256)    131072      leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# norm_12 (BatchNormalization)    (None, 2, 2, 256)    1024        conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 2, 2, 256)    0           norm_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 2, 2, 512)    1179648     leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# norm_13 (BatchNormalization)    (None, 2, 2, 512)    2048        conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 2, 2, 512)    0           norm_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 1, 1, 512)    0           leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 1, 1, 1024)   4718592     max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# norm_14 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_14[0][0]
# __________________________________________________________________________________________________
# conv_15 (Conv2D)                (None, 1, 1, 512)    524288      leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# norm_15 (BatchNormalization)    (None, 1, 1, 512)    2048        conv_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 1, 1, 512)    0           norm_15[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 1, 1, 1024)   4718592     leaky_re_lu_59[0][0]
# __________________________________________________________________________________________________
# norm_16 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 1, 1, 512)    524288      leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# norm_17 (BatchNormalization)    (None, 1, 1, 512)    2048        conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 1, 1, 512)    0           norm_17[0][0]
# __________________________________________________________________________________________________
# conv_18 (Conv2D)                (None, 1, 1, 1024)   4718592     leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# norm_18 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_18[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# norm_19 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_19[0][0]
# __________________________________________________________________________________________________
# conv_21 (Conv2D)                (None, 2, 2, 64)     16384       leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_19[0][0]
# __________________________________________________________________________________________________
# norm_21 (BatchNormalization)    (None, 2, 2, 64)     256         conv_21[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, 2, 2, 64)     0           norm_21[0][0]
# __________________________________________________________________________________________________
# norm_20 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_20[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1, 1, 256)    0           leaky_re_lu_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_20[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1, 1, 1280)   0           lambda_3[0][0]
#                                                                  leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 1, 1, 1024)   11796480    concatenate_3[0][0]
# __________________________________________________________________________________________________
# norm_22 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_22[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1024)         0           leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           10250       flatten_3[0][0]
# ==================================================================================================
# Total params: 50,541,802
# Trainable params: 50,521,130
# Non-trainable params: 20,672
# __________________________________________________________________________________________________

# %%
# determine Loss function and Optimizer
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 104s 2ms/step - loss: 1.4719 - acc: 0.4618 - val_loss: 1.2812 - val_acc: 0.5518
# Epoch 2/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.9654 - acc: 0.6556 - val_loss: 1.3504 - val_acc: 0.5763
# Epoch 3/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.7760 - acc: 0.7288 - val_loss: 1.0213 - val_acc: 0.6575
# Epoch 4/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.6370 - acc: 0.7771 - val_loss: 0.8858 - val_acc: 0.7134
# Epoch 5/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.5687 - acc: 0.8040 - val_loss: 0.8295 - val_acc: 0.7253
# Epoch 6/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.4598 - acc: 0.8401 - val_loss: 1.0156 - val_acc: 0.6945
# Epoch 7/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.3979 - acc: 0.8620 - val_loss: 0.8582 - val_acc: 0.7400
# Epoch 8/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.3412 - acc: 0.8818 - val_loss: 0.9223 - val_acc: 0.7240
# Epoch 9/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.2908 - acc: 0.8981 - val_loss: 1.0247 - val_acc: 0.7131
# Epoch 10/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.2471 - acc: 0.9135 - val_loss: 1.1649 - val_acc: 0.6996
# Epoch 11/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.2062 - acc: 0.9286 - val_loss: 0.9213 - val_acc: 0.7524
# Epoch 12/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.1865 - acc: 0.9349 - val_loss: 0.9543 - val_acc: 0.7586
# Epoch 13/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.1611 - acc: 0.9434 - val_loss: 1.1723 - val_acc: 0.7150
# Epoch 14/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.1444 - acc: 0.9495 - val_loss: 1.1959 - val_acc: 0.7269
# Epoch 15/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.1206 - acc: 0.9582 - val_loss: 1.0775 - val_acc: 0.7454
# Epoch 16/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.1133 - acc: 0.9601 - val_loss: 1.0449 - val_acc: 0.7687
# Epoch 17/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0997 - acc: 0.9648 - val_loss: 1.2284 - val_acc: 0.7324
# Epoch 18/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0897 - acc: 0.9688 - val_loss: 1.1065 - val_acc: 0.7660
# Epoch 19/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0859 - acc: 0.9702 - val_loss: 1.0776 - val_acc: 0.7724
# Epoch 20/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0848 - acc: 0.9700 - val_loss: 1.0993 - val_acc: 0.7701
# Epoch 21/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0738 - acc: 0.9742 - val_loss: 1.1754 - val_acc: 0.7655
# Epoch 22/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0716 - acc: 0.9747 - val_loss: 1.2260 - val_acc: 0.7540
# Epoch 23/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0672 - acc: 0.9763 - val_loss: 1.1336 - val_acc: 0.7790
# Epoch 24/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0758 - acc: 0.9737 - val_loss: 1.1246 - val_acc: 0.7611
# Epoch 25/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0598 - acc: 0.9795 - val_loss: 1.0665 - val_acc: 0.7771
# Epoch 26/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0562 - acc: 0.9807 - val_loss: 1.1303 - val_acc: 0.7803
# Epoch 27/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0558 - acc: 0.9812 - val_loss: 1.0800 - val_acc: 0.7785
# Epoch 28/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0526 - acc: 0.9819 - val_loss: 1.3381 - val_acc: 0.7598
# Epoch 29/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0508 - acc: 0.9832 - val_loss: 1.1007 - val_acc: 0.7784
# Epoch 30/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0510 - acc: 0.9822 - val_loss: 1.2085 - val_acc: 0.7732
# Epoch 31/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0475 - acc: 0.9840 - val_loss: 1.0951 - val_acc: 0.7838
# Epoch 32/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0452 - acc: 0.9844 - val_loss: 1.0564 - val_acc: 0.7830
# Epoch 33/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0457 - acc: 0.9842 - val_loss: 1.2652 - val_acc: 0.7604
# Epoch 34/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0420 - acc: 0.9855 - val_loss: 1.0592 - val_acc: 0.7894
# Epoch 35/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0395 - acc: 0.9864 - val_loss: 1.1891 - val_acc: 0.7726
# Epoch 36/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0385 - acc: 0.9868 - val_loss: 1.1196 - val_acc: 0.7856
# Epoch 37/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0395 - acc: 0.9865 - val_loss: 1.1682 - val_acc: 0.7757
# Epoch 38/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0396 - acc: 0.9865 - val_loss: 1.3409 - val_acc: 0.7522
# Epoch 39/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0442 - acc: 0.9852 - val_loss: 0.9986 - val_acc: 0.7937
# Epoch 40/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0342 - acc: 0.9886 - val_loss: 1.0653 - val_acc: 0.7861
# Epoch 41/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0352 - acc: 0.9879 - val_loss: 1.1217 - val_acc: 0.7888
# Epoch 42/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0305 - acc: 0.9887 - val_loss: 1.2423 - val_acc: 0.7781
# Epoch 43/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0374 - acc: 0.9872 - val_loss: 1.1702 - val_acc: 0.7743
# Epoch 44/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0303 - acc: 0.9897 - val_loss: 1.1062 - val_acc: 0.7922
# Epoch 45/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0345 - acc: 0.9881 - val_loss: 1.1404 - val_acc: 0.7872
# Epoch 46/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0349 - acc: 0.9882 - val_loss: 1.2043 - val_acc: 0.7700
# Epoch 47/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0304 - acc: 0.9897 - val_loss: 1.4555 - val_acc: 0.7321
# Epoch 48/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0283 - acc: 0.9906 - val_loss: 1.1770 - val_acc: 0.7884
# Epoch 49/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0306 - acc: 0.9894 - val_loss: 1.2553 - val_acc: 0.7707
# Epoch 50/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0244 - acc: 0.9916 - val_loss: 1.3543 - val_acc: 0.7684

# %%
# Test the model
score = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Save the trained weights in to .h5 format
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
# Out:
# 10000/10000 [==============================] - 10s 988us/step
# Test loss: 1.3543213735580444
# Test accuracy: 0.7684
# Saved the model to disk

# %%
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
from google.colab import files

files.download('Yolo_Basic_model.h5')
# Out:
# Saved the model to disk
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-7fd61af6c08d> in <module>()
#       3 from google.colab import files
#       4
# ----> 5 files.download('Yolo_Basic_model.h5')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     142       raise OSError(msg)
#     143     else:
# --> 144       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     145
#     146   started = _threading.Event()
#
# FileNotFoundError: Cannot find file: Yolo_Basic_model.h5
